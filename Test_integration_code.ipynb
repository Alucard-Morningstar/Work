# %% [markdown]
# <a href="https://colab.research.google.com/github/Alucard-Morningstar/Work/blob/main/Test_integration_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'/content/data.csv')
df
# Out:
#          Display Name Imagery Shortened.Shortened Display Name.1  \
# 0           Awareness                         NaN     Difference
# 1           Awareness                         NaN     Meaningful
# 2           Awareness                         NaN          Power
# 3           Awareness                         NaN       Salience
# 4      Brand Affinity                         NaN     Difference
# ..                ...                         ...            ...
# 191        Uniqueness                         NaN       Salience
# 192  Uniqueness - T2B                         NaN     Difference
# 193  Uniqueness - T2B                         NaN     Meaningful
# 194  Uniqueness - T2B                         NaN          Power
# 195  Uniqueness - T2B                         NaN       Salience
#
#     TBCA statements Barriers and Facilitators Brand Funnel_Rolling  \
# 0               NaN                       NaN               91.64%
# ...

# %%
df1 = df[['Display Name', 'Brand Funnel_Rolling', 'ChangeVSPP']]
df2 = df[['Imagery Shortened.Shortened', 'Brand Funnel_Rolling', 'ChangeVSPP']]
df3 = df[['Display Name.1', 'MDS']]
df4 = df[['TBCA statements', 'Brand Funnel_Rolling', 'ChangeVSPP']]
df5 = df[['Barriers and Facilitators', 'Brand Funnel_Rolling', 'ChangeVSPP']]

# %%
df1 = df1.drop_duplicates().reset_index(drop=True)

# %%
df2 = df2.dropna().drop_duplicates().reset_index(drop = True)
df2
# Out:
#     Imagery Shortened.Shortened Brand Funnel_Rolling  ChangeVSPP
# 0          Bold lifestyle brand               30.45%        -0.5
# 1      Close to nature's purity                8.74%        -0.2
# 2           Extraordinary brand               15.81%        -1.0
# 3           Has Enjoyable taste               29.44%         0.9
# 4       Meaningful values brand               16.72%         1.2
# 5                 None of these               36.01%        -0.2
# 6   Of real substance and style               15.17%        -1.7
# 7             Personal favorite               23.89%        -4.3
# 8                 Premium brand               15.49%         1.5
# 9       Proudly used and served               21.91%         0.4
# 10            Responsible brand               17.49%        -0.5
# 11                 Social brand               30.79%        -4.1
# 12             Timeless classic               15.38%         3.2
# ...

# %%
df3 = df3.dropna().drop_duplicates().reset_index(drop = True)

# %%
df4 = df4.dropna().drop_duplicates().reset_index(drop = True)
df4
# Out:
#                    TBCA statements Brand Funnel_Rolling  ChangeVSPP
# 0                Company sales rep               21.82%         1.5
# 1                            Email               10.82%        -0.8
# 2   Friends/Family/Insurance Agent               18.37%         5.2
# 3                Internet / Online               15.03%        -1.2
# 4                         Magazine                7.46%         2.6
# 5                             Mail               16.90%        -1.3
# 6                        Newspaper               11.13%         0.4
# 7                   Not seen/heard               10.99%         0.8
# 8                   Online/website               12.37%         0.9
# 9                            Radio               11.44%         1.1
# 10                    Social Media               14.89%        -4.4
# 11                  Somewhere else                8.02%         2.9
# 12                  Sporting event               11.02%         1.0
# ...

# %%
df5 = df5.dropna().drop_duplicates().reset_index(drop = True)
df5
# Out:
#                Barriers and Facilitators Brand Funnel_Rolling  ChangeVSPP
# 0                visible on social media               30.45%        -0.5
# 1   Salesperson/retail staff-recommended                8.74%        -0.2
# 2      Limited edition/special packaging               15.81%        -1.0
# 3              Online ordering available               29.44%         0.9
# 4                 Available by the glass               16.72%         1.2
# 5                       Advertised brand               36.01%        -0.2
# 6    Featured in store circular/magazine               15.17%        -1.7
# 7                    Attractive gift box               23.89%        -4.3
# 8          Celebrity/influencer-endorsed               15.49%         1.5
# 9               Promoted price available               21.91%         0.4
# 10               Home delivery available               17.49%        -0.5
# 11               Strong in-store display               30.79%        -4.1
# ...

# %%
dfs_lst = [df1, df2, df3, df4, df5]

def df_dict(dataframes):
  return {f'df{i+1}': df for i, df in enumerate(dataframes)}

# %%
data_dict = df_dict(dfs_lst)
data_dict

# %%
# !pip install powerbiclient

# %%
from powerbiclient import Report, models, authentication
from powerbiclient.authentication import InteractiveLoginAuthentication

# %%
auth = authentication.InteractiveLoginAuthentication()
# Out:
# WARNING:msal.oauth2cli.authcode:Found no browser in current environment. If this program is being run inside a container which either (1) has access to host network (i.e. started by `docker run --net=host -it ...`), or (2) published port 39455 to host network (i.e. started by `docker run -p 127.0.0.1:39455:39455 -it ...`), you can use browser on host to visit the following link. Otherwise, this auth attempt would either timeout (current timeout setting is None) or be aborted by CTRL+C. Auth URI: https://login.microsoftonline.com/common/oauth2/v2.0/authorize?client_id=1aea3f97-edc6-4453-a59b-b88b0b803711&response_type=code&redirect_uri=http%3A%2F%2Flocalhost%3A39455&scope=https%3A%2F%2Fanalysis.windows.net%2Fpowerbi%2Fapi%2F.default+offline_access+openid+profile&state=yPFIhXwoHbtquerY&code_challenge=gFpEuTxYl7FF_h6VZkyJqcO17JbVr7cnYxir3U7gc-M&code_challenge_method=S256&nonce=5d6aa3ab9789d84ce04d61a5115998d996c01fa3fce92ec79de5859ba266232e&client_info=1
# ...

# %%
# !pip install pyngrok

# %%
from pyngrok import ngrok

dev_derver_port = 3000

public_url = ngrok.connect(dev_derver_port)

print(' * ngrok tunnel"', public_url, '" -> "http://localhost:', dev_derver_port, '"')
# Out:
# ERROR:pyngrok.process.ngrok:t=2024-01-22T06:15:22+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session obj=csess id=e4c2be592a2f err="authentication failed: Usage of ngrok requires a verified account and authtoken.\n\nSign up for an account: https://dashboard.ngrok.com/signup\nInstall your authtoken: https://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_4018\r\n"
# ERROR:pyngrok.process.ngrok:t=2024-01-22T06:15:22+0000 lvl=eror msg="session closing" obj=tunnels.session err="authentication failed: Usage of ngrok requires a verified account and authtoken.\n\nSign up for an account: https://dashboard.ngrok.com/signup\nInstall your authtoken: https://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_4018\r\n"
# ...
